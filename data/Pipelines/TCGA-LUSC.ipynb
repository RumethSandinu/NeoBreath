# %%
import pydicom
# Out:
# /Users/rumethsandinu/Documents/IRP/NeoBreath/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# view dcm properties

IMAGE_PATH = "../Datasets/TCGA-LUSC/manifest-27oBhciT6753657225075401932/TCGA-LUSC/TCGA-34-2605/08-10-1989-NA-CT CHEST-64467/1.000000-scout-93446/1-1.dcm"

properties = pydicom.dcmread(IMAGE_PATH)
print(properties)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.513482823658494545985856858521
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.34'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'LOCALIZER']
# (0008, 0012) Instance Creation Date              DA: '19890810'
# (0008, 0013) Instance Creation Time              TM: '113605'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.513482823658494545985856858521
# (0008, 0020) Study Date                          DA: '19890810'
# (0008, 0021) Series Date                         DA: '19890810'
# (0008, 0022) Acquisition Date                    DA: '19890810'
# (0008, 0023) Content Date                        DA: '19890810'
# (0008, 0030) Study Time                          TM: '113536'
# (0008, 0031) Series Time                         TM: '113536'
# (0008, 0032) Acquisition Time                    TM: '113601'
# (0008, 0033) Content Time                        TM: '113605'
# (0008, 0050) Accession Number                    SH: '7731341270494673'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CT CHEST'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#
#    ---------
# (0008, 103e) Series Description                  LO: 'scout'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed Pro 16'
# (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
# (0009, 1002) [Suite id]                          SH: 'CT01'
# (0009, 1004) [Product id]                        SH: 'LightSpeed Pro'
# (0010, 0010) Patient's Name                      PN: 'TCGA-34-2605'
# (0010, 0020) Patient ID                          LO: 'TCGA-34-2605'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '076Y'
# (0010, 21b0) Additional Patient History          LT: 'F/U LUNG CA.'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence  7 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'TCGA-LUSC\x00'
# (0013, 1013) Private tag data                    UN: b'64504012'
# (0018, 0015) Body Part Examined                  CS: 'LUNG'
# (0018, 0022) Scan Options                        CS: 'SCOUT MODE'
# (0018, 0050) Slice Thickness                     DS: '380.181824'
# (0018, 0060) KVP                                 DS: '120.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: '05MW14.5'
# (0018, 1030) Protocol Name                       LO: '5.1 ROUTINE CHEST WITHOUT'
# (0018, 1100) Reconstruction Diameter             DS: None
# (0018, 1110) Distance Source to Detector         DS: '949.075012'
# (0018, 1111) Distance Source to Patient          DS: '541.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '139.5'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '3872'
# (0018, 1151) X-Ray Tube Current                  IS: '80'
# (0018, 1152) Exposure                            IS: '310'
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: '9600'
# (0018, 1190) Focal Spot(s)                       DS: '0.7'
# (0018, 1210) Convolution Kernel                  SH: 'STANDARD'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
# (0019, 1002) [Detector Channel]                  SL: 912
# (0019, 1003) [Cell number at Theta]              DS: '389.75'
# (0019, 1004) [Cell spacing]                      DS: '1.0239'
# (0019, 100f) [Horiz. Frame of ref.]              DS: '1600.944946'
# (0019, 1011) [Series contrast]                   SS: 0
# (0019, 1018) [First scan ras]                    LO: 'S'
# (0019, 101a) [Last scan ras]                     LO: 'I'
# (0019, 1023) [Table Speed [mm/rotation]]         DS: '0.0'
# (0019, 1024) [Mid Scan Time [sec]]               DS: '0.0'
# (0019, 1025) [Mid scan flag]                     SS: 0
# (0019, 1026) [Tube Azimuth [degree]]             SL: 90
# (0019, 1027) [Rotation Speed [msec]]             DS: '0.0'
# (0019, 102c) [Number of triggers]                SL: 2134
# (0019, 102e) [Angle of first view]               DS: '0.0'
# (0019, 102f) [Trigger frequency]                 DS: '550.0'
# (0019, 1039) [SFOV Type]                         SS: 16
# (0019, 1042) [Segment Number]                    SS: 0
# (0019, 1043) [Total Segments Required]           SS: 0
# (0019, 1047) [View compression factor]           SS: 3
# (0019, 1052) [Recon post proc. Flag]             SS: 1
# (0019, 106a) [Dependent on #views processed]     SS: 2
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.206382517630164051916496664467
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.272181856114963489510533593446
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: [-0.000000, 265.000000, 30.000000]
# (0020, 0037) Image Orientation (Patient)         DS: [0.000000, -1.000000, 0.000000, 0.000000, 0.000000, -1.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.6450.4012.151898168437515227274252015091
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '30.0'
# (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
# (0021, 1003) [Series from which Prescribed]      SS: 1
# (0021, 1035) [Series from which prescribed]      SS: 0
# (0021, 1036) [Image from which prescribed]       SS: 0
# (0021, 1091) [Biopsy position]                   SS: 0
# (0021, 1092) [Biopsy T location]                 FL: 0.0
# (0021, 1093) [Biopsy ref location]               FL: 0.0
# (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
# (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
# (0027, 1010) [Scout Type]                        SS: 2
# (0027, 101c) [Vma mamp]                          SL: 0
# (0027, 101e) [Vma mod]                           SL: 0
# (0027, 101f) [Vma clip]                          SL: 0
# (0027, 1020) [Smart scan ON/OFF flag]            SS: 0
# (0027, 1035) [Plane Type]                        SS: 1
# (0027, 1042) [Center R coord of plane image]     FL: 0.0
# (0027, 1043) [Center A coord of plane image]     FL: 0.0
# (0027, 1044) [Center S coord of plane image]     FL: -160.09091186523438
# (0027, 1045) [Normal R coord]                    FL: -1.0
# (0027, 1046) [Normal A coord]                    FL: -6.123031769111886e-17
# (0027, 1047) [Normal S coord]                    FL: 0.0
# (0027, 1050) [Scan Start Location]               FL: 30.0
# (0027, 1051) [Scan End Location]                 FL: -350.18182373046875
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 697
# (0028, 0011) Columns                             US: 888
# (0028, 0030) Pixel Spacing                       DS: [0.545455, 0.596847]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0303) Longitudinal Temporal Information M SH: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '50.0'
# (0028, 1051) Window Width                        DS: '500.0'
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0244) Performed Procedure Step Start Date DA: '19890810'
# (0040, 0245) Performed Procedure Step Start Time TM: '113536'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'CT CHEST'
# (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
# (0043, 1010) [Window value]                      US: 500
# (0043, 1012) [X-ray chain]                       SS: [99, 99, 99]
# (0043, 1016) [Number of overranges]              SS: -1
# (0043, 101e) [Delta Start Time [msec]]           DS: '0.0'
# (0043, 101f) [Max overranges in a view]          SL: 0
# (0043, 1021) [Corrected after glow terms]        SS: 0
# (0043, 1025) [Reference channels]                SS: [0, 0, 0, 0, 0, 0]
# (0043, 1026) [No views ref chans blocked]        US: [0, 0, 0, 0, 0, 0, 0, 0]
# (0043, 1027) [Scan Pitch Ratio]                  SH: ''
# (0043, 102b) [Private Scan Options]              SS: [8, 0, 0, 0]
# (0043, 1031) [Recon Center Coordinates]          DS: [0.000000, 0.000000]
# (0043, 1040) [Trigger on position]               FL: 89.96610260009766
# (0043, 1041) [Degree of rotation]                FL: 1.6815581571897805e-44
# (0043, 1042) [DAS trigger source]                SL: 0
# (0043, 1043) [DAS fpa gain]                      SL: 0
# (0043, 1044) [DAS output source]                 SL: 0
# (0043, 1045) [DAS ad input]                      SL: 0
# (0043, 1046) [DAS cal mode]                      SL: 0
# (0043, 104d) [Start scan to X-ray on delay]      FL: 0.0
# (0043, 104e) [Duration of X-ray on]              FL: 3.880000114440918
# (0043, 1064) [Image Filter]                      CS: ''
# (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
# (0045, 1001) [Number of Macro Rows in Detector]  SS: 4
# (0045, 1002) [Macro width at ISO Center]         FL: 1.25
# (0045, 1003) [DAS type]                          SS: 13
# (0045, 1004) [DAS gain]                          SS: 6
# (0045, 1006) [Table Direction]                   CS: 'OUT OF GANTRY'
# (0045, 1007) [Z smoothing Factor]                FL: 0.0
# (0045, 1008) [View Weighting Mode]               SS: 0
# (0045, 1009) [Sigma Row number]                  SS: 0
# (0045, 100a) [Minimum DAS value]                 FL: 0.0
# (0045, 100b) [Maximum Offset Value]              FL: 0.0
# (0045, 100c) [Number of Views shifted]           SS: 0
# (0045, 100d) [Z tracking Flag]                   SS: 0
# (0045, 100e) [Mean Z error]                      FL: 0.0
# (0045, 100f) [Z tracking Error]                  FL: 0.0
# (0045, 1010) [Start View 2A]                     SS: 0
# (0045, 1011) [Number of Views 2A]                SS: 0
# (0045, 1012) [Start View 1A]                     SS: 0
# (0045, 1013) [Sigma Mode]                        SS: 0
# (0045, 1014) [Number of Views 1A]                SS: 0
# (0045, 1015) [Start View 2B]                     SS: 0
# (0045, 1016) [Number Views 2B]                   SS: 0
# (0045, 1017) [Start View 1B]                     SS: 0
# (0045, 1018) [Number of Views 1B]                SS: 0
# (0045, 1021) [Iterbone Flag]                     SS: 0
# (0045, 1022) [Perisstaltic Flag]                 SS: 0
# (0045, 1032) [TemporalResolution]                FL: 3.872727155685425
# (0045, 103b) [NoiseReductionImageFilterDesc]     LO: ''
# (0073, 0010) Private Creator                     LO: 'STENTOR'
# (7fe0, 0010) Pixel Data                          OW: Array of 1237872 elements

# %%
import os
import pydicom
from collections import defaultdict
from tqdm import tqdm

# %%
# dataset path
DATASET_PATH = "../Datasets/TCGA-LUSC/manifest-27oBhciT6753657225075401932/TCGA-LUSC"

sop_counts = defaultdict(int)

# collect all DICOM files
all_dcm_files = [os.path.join(root, f)
                 for root, _, files in os.walk(DATASET_PATH)
                 for f in files if f.endswith(".dcm")]

for filepath in tqdm(all_dcm_files, desc="Scanning DICOM files"):

    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        sop_uid = getattr(dcm.file_meta, "MediaStorageSOPClassUID", None)
        if sop_uid:
            sop_counts[sop_uid.name] += 1  # human-readable name
    except Exception as e:
        print(f"Error reading {filepath}: {e}")

#  summary
print("\n===== SOP Class UID Distribution =====\n")
for sop_name, count in sop_counts.items():
    print(f"{sop_name}: {count} files")
# Out:
# Scanning DICOM files: 100%|██████████| 36518/36518 [00:35<00:00, 1036.75it/s]
# ===== SOP Class UID Distribution =====
#
# CT Image Storage: 27342 files
# Positron Emission Tomography Image Storage: 9002 files
# Nuclear Medicine Image Storage: 10 files
# Secondary Capture Image Storage: 164 files

# %%
img_type_counts = defaultdict(int)

# collect all DICOM files
all_dcm_files = [os.path.join(root, f)
                 for root, _, files in os.walk(DATASET_PATH)
                 for f in files if f.endswith(".dcm")]

for filepath in tqdm(all_dcm_files, desc="Scanning DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)

        # extract Image Type (0008,0008)
        img_type = getattr(dcm, "ImageType", None)
        if img_type:

            # convert to tuple so it's hashable
            img_type_counts[tuple(img_type)] += 1
    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print("\n===== Image Type Distribution =====\n")
for img_type, count in sorted(img_type_counts.items(), key=lambda x: -x[1]):
    print(f"{list(img_type)}: {count} files")
# Out:
# Scanning DICOM files: 100%|██████████| 36518/36518 [00:34<00:00, 1045.26it/s]
# ===== Image Type Distribution =====
#
# ['ORIGINAL', 'PRIMARY', 'AXIAL']: 16523 files
# ['ORIGINAL', 'PRIMARY']: 8687 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']: 7298 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELIX']: 1260 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'CSA MPR', '', 'CSAPARALLEL', 'AXIAL', 'CT_SOM5 SPI']: 632 files
# ['DERIVED', 'PRIMARY', 'AXIAL']: 534 files
# ['DERIVED', 'SECONDARY', 'MPR']: 431 files
# ['DERIVED', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']: 260 files
# ['DERIVED', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPO']: 153 files
# ['DERIVED', 'SECONDARY', 'REFORMATTED']: 148 files
# ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']: 100 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'CSA FUSED MPR', '', 'CSAPARALLEL', 'AXIAL', 'CT_SOM5 SPI']: 100 files
# ['DERIVED', 'SECONDARY', 'AXIAL', 'CSA MPR', 'CSAMANIPULATED']: 79 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER']: 75 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM4 SPI']: 69 files
# ['ORIGINAL', 'SECONDARY', 'MIP']: 64 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'CSA MIP', 'CSAMANIPULATED']: 32 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'CT_SOM5 TOP']: 24 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'CSA MPR', 'CSAMANIPULATED']: 16 files
# ['ORIGINAL', 'PRIMARY', 'STATIC', 'EMISSION']: 8 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'PS']: 4 files
# ['DERIVED', 'SECONDARY', 'LOCALIZER', 'CSA MPR', '', 'CSAPARALLEL', 'AXIAL', 'CT_SOM5 SPI']: 4 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'ES']: 3 files
# ['DERIVED', 'PRIMARY', '']: 3 files
# ['DERIVED', 'PRIMARY', 'LOCALIZER', 'CT_SOM5 SPO']: 3 files
# ['ORIGINAL', 'PRIMARY', 'DYNAMIC', 'EMISSION']: 2 files
# ['DERIVED', 'PRIMARY', 'LOCALIZER', 'CT_SOM5 TOP']: 2 files
# ['DERIVED', 'SECONDARY', 'LOCALIZER', 'CSA MPR', 'CSAMANIPULATED']: 1 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 MON', 'PMON']: 1 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 MON']: 1 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'CT_SOM4 TOP']: 1 files

# %%
# counters
slice_counts = {"PET": 0, "CT": 0}
patient_counts = {"PET": set(), "CT": set()}

# valid SOP classes
SOP_UIDS = {
    "PET": "1.2.840.10008.5.1.4.1.1.128",
    "CT": "1.2.840.10008.5.1.4.1.1.2"
}

def is_valid_image(dcm):
    """Return True if DICOM is ORIGINAL + PRIMARY and not derived/reformatted"""
    if not hasattr(dcm, "ImageType"):
        return False
    
    img_type = [s.upper() for s in dcm.ImageType]
    if "ORIGINAL" not in img_type or "PRIMARY" not in img_type:
        return False
    
    bad_keywords = ["DERIVED", "SECONDARY", "LOCALIZER", "QC", "MONO", "MPR"]
    if any(bad in img_type for bad in bad_keywords):
        return False
    
    return True

# walk through dataset
for root, _, files in os.walk(DATASET_PATH):
    for f in files:
        if not f.endswith(".dcm"):
            continue
        
        filepath = os.path.join(root, f)
        try:
            dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
            modality = getattr(dcm, "Modality", "")
            sop_uid = str(getattr(dcm, "SOPClassUID", ""))
            patient_id = str(dcm.PatientID)

            if modality == "PT" and sop_uid == SOP_UIDS["PET"] and is_valid_image(dcm):
                slice_counts["PET"] += 1
                patient_counts["PET"].add(patient_id)

            elif modality == "CT" and sop_uid == SOP_UIDS["CT"] and is_valid_image(dcm):
                slice_counts["CT"] += 1
                patient_counts["CT"].add(patient_id)

        except Exception as e:
            print(f"Error reading {filepath}: {e}")

# summary
print(f"PET : {slice_counts['PET']} slices from {len(patient_counts['PET'])} patients")
print(f"CT: {slice_counts['CT']} slices from {len(patient_counts['CT'])} patients")
# Out:
# PET : 8687 slices from 22 patients
# CT: 24966 slices from 37 patients

# %%
import shutil

# %%
OUTPUT_PATH = "../raw/PET/G"

# counters
slice_count = 0
patient_set = set()

# ensure output folder exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# collect all DICOM files
all_dcm_files = [
    os.path.join(root, f)
    for root, _, files in os.walk(DATASET_PATH)
    for f in files if f.endswith(".dcm")
]

# process files
for filepath in tqdm(all_dcm_files, desc="Processing PET DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        modality = getattr(dcm, "Modality", "")
        sop_uid = str(getattr(dcm, "SOPClassUID", ""))

        if modality == "PT" and sop_uid == SOP_UIDS["PET"] and is_valid_image(dcm):
            patient_id = str(dcm.PatientID)
            full_patient_id = f"TCGA-LUSC-{patient_id}"

            dest_dir = os.path.join(OUTPUT_PATH, full_patient_id)
            os.makedirs(dest_dir, exist_ok=True)

            dest_file = os.path.join(dest_dir, os.path.basename(filepath))
            if not os.path.exists(dest_file):
                shutil.copy2(filepath, dest_file)

            slice_count += 1
            patient_set.add(full_patient_id)

    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print(f"PET: {slice_count} slices copied from {len(patient_set)} patients")
# Out:
# Processing PET DICOM files: 100%|██████████| 36518/36518 [00:38<00:00, 944.21it/s]
# PET: 8687 slices copied from 22 patients

# %%
OUTPUT_PATH = "../raw/CT/G"

# counters
slice_count = 0
patient_set = set()

# ensure output folder exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# collect all DICOM files
all_dcm_files = [
    os.path.join(root, f)
    for root, _, files in os.walk(DATASET_PATH)
    for f in files if f.endswith(".dcm")
]

# process files
for filepath in tqdm(all_dcm_files, desc="Processing CT DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        modality = getattr(dcm, "Modality", "")
        sop_uid = str(getattr(dcm, "SOPClassUID", ""))

        if modality == "CT" and sop_uid == SOP_UIDS["CT"] and is_valid_image(dcm):
            patient_id = str(dcm.PatientID)
            full_patient_id = f"TCGA-LUSC-{patient_id}"

            dest_dir = os.path.join(OUTPUT_PATH, full_patient_id)
            os.makedirs(dest_dir, exist_ok=True)

            dest_file = os.path.join(dest_dir, os.path.basename(filepath))
            if not os.path.exists(dest_file):
                shutil.copy2(filepath, dest_file)

            slice_count += 1
            patient_set.add(full_patient_id)

    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print(f"CT: {slice_count} slices copied from {len(patient_set)} patients")
# Out:
# Processing CT DICOM files: 100%|██████████| 36518/36518 [00:49<00:00, 731.72it/s]
# CT: 24966 slices copied from 37 patients
