# %%
import pydicom
# Out:
# /Users/rumethsandinu/Documents/IRP/NeoBreath/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# view dcm properties

IMAGE_PATH = "../Datasets/CPTAC-LSCC/manifest-1677266205028/CPTAC-LSCC/C3L-01000/06-09-2011-NA-MSKT organov grudnoy k-18628/3.000000-LUNG 1.25mm-28122/1-001.dcm"

properties = pydicom.dcmread(IMAGE_PATH)
print(properties)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.216833447145256351340320153667
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20110609'
# (0008, 0013) Instance Creation Time              TM: '154816'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.216833447145256351340320153667
# (0008, 0020) Study Date                          DA: '20110609'
# (0008, 0021) Series Date                         DA: '20110609'
# (0008, 0022) Acquisition Date                    DA: '20110609'
# (0008, 0023) Content Date                        DA: '20110609'
# (0008, 0030) Study Time                          TM: '154626'
# (0008, 0031) Series Time                         TM: '154735'
# (0008, 0032) Acquisition Time                    TM: '154756.742941'
# (0008, 0033) Content Time                        TM: '154816'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'MSKT organov grudnoy k'
# (0008, 103e) Series Description                  LO: 'LUNG 1.25mm'
# (0008, 1090) Manufacturer's Model Name           LO: 'Optima CT660'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.673079780724926389963058818628
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.211163177248400341959827776338
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.182109185729773595904587552654
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.344616165578242453337184673892
# (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
# (0009, 1001) [Full fidelity]                     LO: 'CT_LIGHTSPEED'
# (0009, 10e3) [Equipment UID]                     UI: ''
# (0010, 0010) Patient's Name                      PN: 'C3L-01000'
# (0010, 0020) Patient ID                          LO: 'C3L-01000'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '60'
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 21b0) Additional Patient History          LT: 'De-identified'
# (0010, 4000) Patient Comments                    LT: 'De-identified'
# (0012, 0050) Clinical Trial Time Point ID        LO: '-116'
# (0012, 0051) Clinical Trial Time Point Descripti ST: 'Days offset from diagnosis'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence  8 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113104'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Structured Content Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'CPTAC-LSCC'
# (0013, 1013) Private tag data                    UN: b'26921975'
# (0013, 1015) Private tag data                    UN: b'1 '
# (0018, 0022) Scan Options                        CS: 'HELICAL MODE'
# (0018, 0050) Slice Thickness                     DS: '1.25'
# (0018, 0060) KVP                                 DS: '120.0'
# (0018, 0088) Spacing Between Slices              DS: '5.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: 'cj2_5m3sp4.5'
# (0018, 1030) Protocol Name                       LO: '5.1 Chest standard + CONTRAST (V=1ml/kg)   (MEDIASTINUM)'
# (0018, 1100) Reconstruction Diameter             DS: '433.0'
# (0018, 1110) Distance Source to Detector         DS: '949.147'
# (0018, 1111) Distance Source to Patient          DS: '541.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '149.5'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '800'
# (0018, 1151) X-Ray Tube Current                  IS: '200'
# (0018, 1152) Exposure                            IS: '5'
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: '24000'
# (0018, 1190) Focal Spot(s)                       DS: '0.7'
# (0018, 1210) Convolution Kernel                  SH: 'LUNG'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9305) Revolution Time                     FD: 0.8
# (0018, 9306) Single Collimation Width            FD: 0.625
# (0018, 9307) Total Collimation Width             FD: 40.0
# (0018, 9309) Table Speed                         FD: 49.21875
# (0018, 9310) Table Feed per Rotation             FD: 39.375
# (0018, 9311) Spiral Pitch Factor                 FD: 0.984375
# (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
# (0019, 1002) [Detector Channel]                  SL: 912
# (0019, 1003) [Cell number at Theta]              DS: '389.75'
# (0019, 1004) [Cell spacing]                      DS: '1.0239'
# (0019, 1011) [Series contrast]                   SS: 0
# (0019, 1018) [First scan ras]                    LO: 'S'
# (0019, 101a) [Last scan ras]                     LO: 'I'
# (0019, 1023) [Table Speed [mm/rotation]]         DS: '39.375'
# (0019, 1024) [Mid Scan Time [sec]]               DS: '0.463415'
# (0019, 1025) [Mid scan flag]                     SS: 1
# (0019, 1026) [Tube Azimuth [degree]]             SL: -1
# (0019, 1027) [Rotation Speed [msec]]             DS: '0.8'
# (0019, 102c) [Number of triggers]                SL: 8900
# (0019, 102e) [Angle of first view]               DS: '0.0'
# (0019, 102f) [Trigger frequency]                 DS: '1230.0'
# (0019, 1039) [SFOV Type]                         SS: 1024
# (0019, 1042) [Segment Number]                    SS: 0
# (0019, 1043) [Total Segments Required]           SS: 0
# (0019, 1047) [View compression factor]           SS: 1
# (0019, 1052) [Recon post proc. Flag]             SS: 1
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.673079780724926389963058818628
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.397384838062551337026550528122
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '3'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: [-209.000, -233.300, 15.250]
# (0020, 0037) Image Orientation (Patient)         DS: [1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.2692.1975.249931493104843255168153897996
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '15.25'
# (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
# (0021, 1091) [Biopsy position]                   SS: 0
# (0021, 1092) [Biopsy T location]                 FL: 0.0
# (0021, 1093) [Biopsy ref location]               FL: 0.0
# (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
# (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
# (0027, 1010) [Scout Type]                        SS: 0
# (0027, 101c) [Vma mamp]                          SL: 0
# (0027, 101e) [Vma mod]                           SL: 0
# (0027, 101f) [Vma clip]                          SL: 0
# (0027, 1020) [Smart scan ON/OFF flag]            SS: 0
# (0027, 1035) [Plane Type]                        SS: 2
# (0027, 1042) [Center R coord of plane image]     FL: -7.5
# (0027, 1043) [Center A coord of plane image]     FL: 16.799999237060547
# (0027, 1044) [Center S coord of plane image]     FL: 15.25
# (0027, 1045) [Normal R coord]                    FL: 0.0
# (0027, 1046) [Normal A coord]                    FL: -0.0
# (0027, 1047) [Normal S coord]                    FL: 1.0
# (0027, 1050) [Scan Start Location]               FL: 0.0
# (0027, 1051) [Scan End Location]                 FL: 0.0
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.845703, 0.845703]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0120) Pixel Padding Value                 SS: -2000
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '-600.0'
# (0028, 1051) Window Width                        DS: '1500.0'
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0032, 4000) Study Comments                      LT: 'De-identified'
# (0040, 0244) Performed Procedure Step Start Date DA: '20110609'
# (0040, 0245) Performed Procedure Step Start Time TM: '154626'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MSKT organov grudnoy k'
# (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
# (0043, 1010) [Window value]                      US: 1500
# (0043, 1012) [X-ray chain]                       SS: [99, 99, 99]
# (0043, 1016) [Number of overranges]              SS: 0
# (0043, 101e) [Delta Start Time [msec]]           DS: '0.063415'
# (0043, 101f) [Max overranges in a view]          SL: 0
# (0043, 1021) [Corrected after glow terms]        SS: 0
# (0043, 1025) [Reference channels]                SS: [0, 0, 0, 0, 0, 0]
# (0043, 1026) [No views ref chans blocked]        US: [0, 0, 0, 0]
# (0043, 1027) [Scan Pitch Ratio]                  SH: '0.984:1'
# (0043, 1031) [Recon Center Coordinates]          DS: [-7.500000, 16.800000]
# (0043, 1040) [Trigger on position]               FL: 72.1852035522461
# (0043, 1041) [Degree of rotation]                FL: 3255.566650390625
# (0043, 1042) [DAS trigger source]                SL: 0
# (0043, 1043) [DAS fpa gain]                      SL: 0
# (0043, 1044) [DAS output source]                 SL: 0
# (0043, 1045) [DAS ad input]                      SL: 0
# (0043, 1046) [DAS cal mode]                      SL: 0
# (0043, 104d) [Start scan to X-ray on delay]      FL: 0.0
# (0043, 104e) [Duration of X-ray on]              FL: 7.235772132873535
# (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
# (0045, 1001) [Number of Macro Rows in Detector]  SS: 64
# (0045, 1002) [Macro width at ISO Center]         FL: 0.625
# (0045, 1003) [DAS type]                          SS: 24
# (0045, 1004) [DAS gain]                          SS: 4
# (0045, 1006) [Table Direction]                   CS: 'INTO GANTRY'
# (0045, 1007) [Z smoothing Factor]                FL: 0.0
# (0045, 1008) [View Weighting Mode]               SS: 0
# (0045, 1009) [Sigma Row number]                  SS: 0
# (0045, 100a) [Minimum DAS value]                 FL: 0.0
# (0045, 100b) [Maximum Offset Value]              FL: 0.0
# (0045, 100c) [Number of Views shifted]           SS: 0
# (0045, 100d) [Z tracking Flag]                   SS: 0
# (0045, 100e) [Mean Z error]                      FL: 0.0
# (0045, 100f) [Z tracking Error]                  FL: 0.0
# (0045, 1010) [Start View 2A]                     SS: 0
# (0045, 1011) [Number of Views 2A]                SS: 0
# (0045, 1012) [Start View 1A]                     SS: 0
# (0045, 1013) [Sigma Mode]                        SS: 0
# (0045, 1014) [Number of Views 1A]                SS: 0
# (0045, 1015) [Start View 2B]                     SS: 0
# (0045, 1016) [Number Views 2B]                   SS: 0
# (0045, 1018) [Number of Views 1B]                SS: 0
# (0045, 1021) [Iterbone Flag]                     SS: 0
# (0045, 1022) [Perisstaltic Flag]                 SS: 0
# (0045, 1032) [TemporalResolution]                FL: 0.800000011920929
# (0045, 103b) [NoiseReductionImageFilterDesc]     LO: ''
# (0053, 0010) Private Creator                     LO: 'GEHC_CT_ADVAPP_001'
# (0053, 1020) [ShuttleFlag]                       IS: '0'
# (0053, 1060) [reconFlipRotateAnno]               SH: ''
# (0053, 1061) [highResolutionFlag]                SH: '0'
# (0053, 1062) [RespiratoryFlag]                   SH: '0'
# (0053, 1064) Private tag data                    UN: b'1 '
# (0053, 1065) Private tag data                    UN: b'36'
# (0053, 1067) Private tag data                    UN: b'0 '
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %%
import os
import pydicom
from collections import defaultdict
from tqdm import tqdm

# %%
# dataset path
DATASET_PATH = "../Datasets/CPTAC-LSCC/manifest-1677266205028/CPTAC-LSCC"

sop_counts = defaultdict(int)

# collect all DICOM files
all_dcm_files = [os.path.join(root, f)
                 for root, _, files in os.walk(DATASET_PATH)
                 for f in files if f.endswith(".dcm")]

for filepath in tqdm(all_dcm_files, desc="Scanning DICOM files"):

    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        sop_uid = getattr(dcm.file_meta, "MediaStorageSOPClassUID", None)
        if sop_uid:
            sop_counts[sop_uid.name] += 1  # human-readable name
    except Exception as e:
        print(f"Error reading {filepath}: {e}")

#  summary
print("\n===== SOP Class UID Distribution =====\n")
for sop_name, count in sop_counts.items():
    print(f"{sop_name}: {count} files")
# Out:
# Scanning DICOM files: 100%|██████████| 51000/51000 [00:47<00:00, 1063.20it/s]
# ===== SOP Class UID Distribution =====
#
# Positron Emission Tomography Image Storage: 5560 files
# CT Image Storage: 45437 files
# Secondary Capture Image Storage: 3 files

# %%
img_type_counts = defaultdict(int)

# collect all DICOM files
all_dcm_files = [os.path.join(root, f)
                 for root, _, files in os.walk(DATASET_PATH)
                 for f in files if f.endswith(".dcm")]

for filepath in tqdm(all_dcm_files, desc="Scanning DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)

        # extract Image Type (0008,0008)
        img_type = getattr(dcm, "ImageType", None)
        if img_type:

            # convert to tuple so it's hashable
            img_type_counts[tuple(img_type)] += 1
    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print("\n===== Image Type Distribution =====\n")
for img_type, count in sorted(img_type_counts.items(), key=lambda x: -x[1]):
    print(f"{list(img_type)}: {count} files")
# Out:
# Scanning DICOM files: 100%|██████████| 51000/51000 [00:47<00:00, 1066.61it/s]
# ===== Image Type Distribution =====
#
# ['ORIGINAL', 'PRIMARY', 'AXIAL']: 21056 files
# ['DERIVED', 'SECONDARY', 'OTHER']: 10911 files
# ['ORIGINAL', 'PRIMARY']: 4651 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELIX']: 3426 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'VOLUME']: 1933 files
# ['DERIVED', 'SECONDARY', 'MPR']: 1760 files
# ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']: 1332 files
# ['DERIVED', 'SECONDARY', 'MPR', 'MIP']: 652 files
# ['DERIVED', 'PRIMARY', 'MPR']: 531 files
# ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']: 518 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'CSA MPR', '', 'CSAPARALLEL', 'AXIAL', 'CT_SOM5 SPI']: 267 files
# ['DERIVED', 'SECONDARY', 'REFORMATTED', 'MIP']: 258 files
# ['DERIVED', 'SECONDARY', '', 'MPR']: 256 files
# ['DERIVED', 'SECONDARY', 'OTHER', 'MPR']: 128 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER']: 26 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'PS']: 5 files
# ['DERIVED', 'SECONDARY', 'REFORMATTED']: 4 files
# ['DERIVED', 'SECONDARY', 'CURVED']: 2 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'ES']: 2 files
# ['DERIVED', 'SECONDARY', 'LOCALIZER', 'CSA MPR', '', 'CSAPARALLEL', 'AXIAL', 'CT_SOM5 SPI']: 2 files
# ['ORIGINAL', 'PRIMARY', 'LOCALIZER', 'CT_SOM5 TOP']: 2 files
# ['DERIVED', 'SECONDARY', 'DISPLAY']: 1 files

# %%
# counters
slice_counts = {"PET": 0, "CT": 0}
patient_counts = {"PET": set(), "CT": set()}

# valid SOP classes
SOP_UIDS = {
    "PET": "1.2.840.10008.5.1.4.1.1.128",
    "CT": "1.2.840.10008.5.1.4.1.1.2"
}

def is_valid_image(dcm):
    """Return True if DICOM is ORIGINAL + PRIMARY and not derived/reformatted"""
    if not hasattr(dcm, "ImageType"):
        return False
    
    img_type = [s.upper() for s in dcm.ImageType]
    if "ORIGINAL" not in img_type or "PRIMARY" not in img_type:
        return False
    
    bad_keywords = ["DERIVED", "SECONDARY", "LOCALIZER", "QC", "MONO", "MPR"]
    if any(bad in img_type for bad in bad_keywords):
        return False
    
    return True

# walk through dataset
for root, _, files in os.walk(DATASET_PATH):
    for f in files:
        if not f.endswith(".dcm"):
            continue
        
        filepath = os.path.join(root, f)
        try:
            dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
            modality = getattr(dcm, "Modality", "")
            sop_uid = str(getattr(dcm, "SOPClassUID", ""))
            patient_id = str(dcm.PatientID)

            if modality == "PT" and sop_uid == SOP_UIDS["PET"] and is_valid_image(dcm):
                slice_counts["PET"] += 1
                patient_counts["PET"].add(patient_id)

            elif modality == "CT" and sop_uid == SOP_UIDS["CT"] and is_valid_image(dcm):
                slice_counts["CT"] += 1
                patient_counts["CT"].add(patient_id)

        except Exception as e:
            print(f"Error reading {filepath}: {e}")

# summary
print(f"PET: {slice_counts['PET']} slices from {len(patient_counts['PET'])} patients")
print(f"CT: {slice_counts['CT']} slices from {len(patient_counts['CT'])} patients")
# Out:
# PET: 4651 slices from 6 patients
# CT: 27747 slices from 23 patients

# %%
import shutil

# %%
OUTPUT_PATH = "../raw/PET/G"

# counters
slice_count = 0
patient_set = set()

# ensure output folder exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# collect all DICOM files
all_dcm_files = [
    os.path.join(root, f)
    for root, _, files in os.walk(DATASET_PATH)
    for f in files if f.endswith(".dcm")
]

# process files
for filepath in tqdm(all_dcm_files, desc="Processing PET DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        modality = getattr(dcm, "Modality", "")
        sop_uid = str(getattr(dcm, "SOPClassUID", ""))

        if modality == "PT" and sop_uid == SOP_UIDS["PET"] and is_valid_image(dcm):
            patient_id = str(dcm.PatientID)
            full_patient_id = f"CPTACT-LSCC-{patient_id}"

            dest_dir = os.path.join(OUTPUT_PATH, full_patient_id)
            os.makedirs(dest_dir, exist_ok=True)

            dest_file = os.path.join(dest_dir, os.path.basename(filepath))
            if not os.path.exists(dest_file):
                shutil.copy2(filepath, dest_file)

            slice_count += 1
            patient_set.add(full_patient_id)

    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print(f"PET: {slice_count} slices copied from {len(patient_set)} patients")
# Out:
# Processing PET DICOM files: 100%|██████████| 51000/51000 [00:49<00:00, 1023.27it/s]
# PET: 4651 slices copied from 6 patients

# %%
OUTPUT_PATH = "../raw/CT/G"

# counters
slice_count = 0
patient_set = set()

# ensure output folder exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# collect all DICOM files
all_dcm_files = [
    os.path.join(root, f)
    for root, _, files in os.walk(DATASET_PATH)
    for f in files if f.endswith(".dcm")
]

# process files
for filepath in tqdm(all_dcm_files, desc="Processing CT DICOM files"):
    try:
        dcm = pydicom.dcmread(filepath, stop_before_pixels=True)
        modality = getattr(dcm, "Modality", "")
        sop_uid = str(getattr(dcm, "SOPClassUID", ""))

        if modality == "CT" and sop_uid == SOP_UIDS["CT"] and is_valid_image(dcm):
            patient_id = str(dcm.PatientID)
            full_patient_id = f"CPTACT-LSCC-{patient_id}"

            dest_dir = os.path.join(OUTPUT_PATH, full_patient_id)
            os.makedirs(dest_dir, exist_ok=True)

            dest_file = os.path.join(dest_dir, os.path.basename(filepath))
            if not os.path.exists(dest_file):
                shutil.copy2(filepath, dest_file)

            slice_count += 1
            patient_set.add(full_patient_id)

    except Exception as e:
        print(f"Error reading {filepath}: {e}")

# summary
print(f"CT: {slice_count} slices copied from {len(patient_set)} patients")
# Out:
# Processing CT DICOM files: 100%|██████████| 51000/51000 [01:02<00:00, 817.84it/s]
# CT: 27747 slices copied from 23 patients
